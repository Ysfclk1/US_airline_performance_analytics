# %%
import pandas as pd

# %%
df = pd.read_csv("2016.csv")

# %%
df
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2016-01-01         DL               1248    DTW  LAX          1935
# 1        2016-01-01         DL               1251    ATL  GRR          2125
# 2        2016-01-01         DL               1254    LAX  ATL          2255
# 3        2016-01-01         DL               1255    SLC  ATL          1656
# 4        2016-01-01         DL               1256    BZN  MSP           900
# ...             ...        ...                ...    ...  ...           ...
# 1106965  2016-03-16         B6                340    SJU  STX          1457
# 1106966  2016-03-16         B6                341    STX  SJU          1615
# 1106967  2016-03-16         B6                347    OAK  LGB          1833
# 1106968  2016-03-16         B6                348    LGB  OAK          1635
# 1106969  2016-03-16         B6                350    TPA  DCA          1005
#
#          DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0          1935.0        0.0      23.0      1958.0  ...             309.0
# 1          2130.0        5.0      13.0      2143.0  ...             116.0
# 2          2256.0        1.0      19.0      2315.0  ...             245.0
# 3          1700.0        4.0      12.0      1712.0  ...             213.0
# 4          1012.0       72.0      63.0      1115.0  ...             136.0
# ...           ...        ...       ...         ...  ...               ...
# 1106965    1606.0       69.0      10.0      1616.0  ...              40.0
# 1106966    1712.0       57.0       6.0      1718.0  ...              44.0
# 1106967    1827.0       -6.0       7.0      1834.0  ...              76.0
# 1106968    1629.0       -6.0      13.0      1642.0  ...              77.0
# 1106969    1003.0       -2.0      15.0      1018.0  ...             131.0
#
#          ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 0                      285.0     249.0    1979.0            NaN
# 1                      109.0      92.0     640.0            NaN
# 2                      231.0     207.0    1947.0            NaN
# 3                      193.0     173.0    1590.0            NaN
# 4                      188.0     121.0     874.0           72.0
# ...                      ...       ...       ...            ...
# 1106965                 33.0      21.0      94.0           16.0
# 1106966                 37.0      29.0      94.0            3.0
# 1106967                 68.0      58.0     353.0            NaN
# 1106968                 73.0      56.0     353.0            NaN
# 1106969                126.0       NaN       NaN            NaN
#
#          WEATHER_DELAY NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  \
# 0                  NaN       NaN             NaN                  NaN
# 1                  NaN       NaN             NaN                  NaN
# 2                  NaN       NaN             NaN                  NaN
# 3                  NaN       NaN             NaN                  NaN
# 4                  0.0      52.0             0.0                  0.0
# ...                ...       ...             ...                  ...
# 1106965            0.0       0.0             0.0                 46.0
# 1106966            0.0       0.0             0.0                 47.0
# 1106967            NaN       NaN             NaN                  NaN
# 1106968            NaN       NaN             NaN                  NaN
# 1106969            NaN       NaN             NaN                  NaN
#
#          Unnamed: 27
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 1106965          NaN
# 1106966          NaN
# 1106967          NaN
# 1106968          NaN
# 1106969          NaN
#
# [1106970 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['FL_DATE', 'OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST',
#        'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY',
#        'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'Unnamed: 27'],
#       dtype='object')

# %%
df = df.drop(columns=["Unnamed: 27"])

# %%
null_info = pd.DataFrame({
    'Null Sayısı': df.isnull().sum(),
    'Null Yüzdesi': (df.isnull().sum() / len(df)) * 100
})
print(null_info)
# Out:
#                      Null Sayısı  Null Yüzdesi
# FL_DATE                        0      0.000000
# OP_CARRIER                     0      0.000000
# OP_CARRIER_FL_NUM              0      0.000000
# ORIGIN                         0      0.000000
# DEST                           0      0.000000
# CRS_DEP_TIME                   0      0.000000
# DEP_TIME                   20154      1.820646
# DEP_DELAY                  20154      1.820646
# TAXI_OUT                   20543      1.855787
# WHEELS_OFF                 20543      1.855787
# WHEELS_ON                  21260      1.920558
# TAXI_IN                    21260      1.920558
# CRS_ARR_TIME                   0      0.000000
# ARR_TIME                   21260      1.920558
# ARR_DELAY                  22977      2.075666
# CANCELLED                      0      0.000000
# CANCELLATION_CODE        1086288     98.131657
# DIVERTED                       0      0.000000
# CRS_ELAPSED_TIME               0      0.000000
# ACTUAL_ELAPSED_TIME        22977      2.075666
# AIR_TIME                   22978      2.075756
# DISTANCE                       1      0.000090
# CARRIER_DELAY             935725     84.530294
# WEATHER_DELAY             935725     84.530294
# NAS_DELAY                 935725     84.530294
# SECURITY_DELAY            935725     84.530294
# LATE_AIRCRAFT_DELAY       935725     84.530294

# %%
    parse_dates=["FL_DATE"],   # uçuş tarihi
    dtype={
        "OP_CARRIER": "category",
        "ORIGIN": "category",
        "DEST": "category"
    }

print("Şekil (satır, kolon):", df.shape)
print("\nİlk 5 satır:")
display(df.head())

print("\nKolonlar:")
print(df.columns.tolist())

print("\nDtype bilgisi:")
print(df.dtypes)
# Out:
# Şekil (satır, kolon): (1106970, 27)
#
# İlk 5 satır:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2016-01-01         DL               1248    DTW  LAX          1935
# 1  2016-01-01         DL               1251    ATL  GRR          2125
# 2  2016-01-01         DL               1254    LAX  ATL          2255
# 3  2016-01-01         DL               1255    SLC  ATL          1656
# 4  2016-01-01         DL               1256    BZN  MSP           900
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  DIVERTED  CRS_ELAPSED_TIME  \
# 0    1935.0        0.0      23.0      1958.0  ...       0.0             309.0
# 1    2130.0        5.0      13.0      2143.0  ...       0.0             116.0
# 2    2256.0        1.0      19.0      2315.0  ...       0.0             245.0
# 3    1700.0        4.0      12.0      1712.0  ...       0.0             213.0
# 4    1012.0       72.0      63.0      1115.0  ...       0.0             136.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY WEATHER_DELAY  \
# 0                285.0     249.0    1979.0            NaN           NaN
# 1                109.0      92.0     640.0            NaN           NaN
# 2                231.0     207.0    1947.0            NaN           NaN
# 3                193.0     173.0    1590.0            NaN           NaN
# 4                188.0     121.0     874.0           72.0           0.0
#
#    NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 0        NaN             NaN                  NaN
# 1        NaN             NaN                  NaN
# 2        NaN             NaN                  NaN
# 3        NaN             NaN                  NaN
# 4       52.0             0.0                  0.0
#
# [5 rows x 27 columns]
# Kolonlar:
# ['FL_DATE', 'OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'WHEELS_OFF', 'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY', 'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY']
#
# Dtype bilgisi:
# FL_DATE                 object
# OP_CARRIER              object
# OP_CARRIER_FL_NUM        int64
# ORIGIN                  object
# DEST                    object
# CRS_DEP_TIME             int64
# DEP_TIME               float64
# DEP_DELAY              float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# WHEELS_ON              float64
# TAXI_IN                float64
# CRS_ARR_TIME             int64
# ARR_TIME               float64
# ARR_DELAY              float64
# CANCELLED              float64
# CANCELLATION_CODE       object
# DIVERTED               float64
# CRS_ELAPSED_TIME       float64
# ACTUAL_ELAPSED_TIME    float64
# AIR_TIME               float64
# DISTANCE               float64
# CARRIER_DELAY          float64
# WEATHER_DELAY          float64
# NAS_DELAY              float64
# SECURITY_DELAY         float64
# LATE_AIRCRAFT_DELAY    float64
# dtype: object

# %%
# Cancelled ve Diverted ile eksikliği inceleme
if "CANCELLED" in df.columns:
    print("\nCANCELLED dağılımı:")
    display(df["CANCELLED"].value_counts(dropna=False))

if "DIVERTED" in df.columns:
    print("\nDIVERTED dağılımı:")
    display(df["DIVERTED"].value_counts(dropna=False))

# Cancelled satırlarındaki eksiklik
if "CANCELLED" in df.columns:
    print("\nCANCELLED = 1 satırlarda eksik oranları:")
    display(df[df["CANCELLED"] == 1].isna().mean().sort_values(ascending=False))
# Out:
# CANCELLED dağılımı:
# CANCELLED
# 0.0    1086288
# 1.0      20682
# Name: count, dtype: int64
# DIVERTED dağılımı:
# DIVERTED
# 0.0    1104675
# 1.0       2295
# Name: count, dtype: int64
# CANCELLED = 1 satırlarda eksik oranları:
# WHEELS_ON              1.000000
# NAS_DELAY              1.000000
# LATE_AIRCRAFT_DELAY    1.000000
# ACTUAL_ELAPSED_TIME    1.000000
# AIR_TIME               1.000000
# CARRIER_DELAY          1.000000
# WEATHER_DELAY          1.000000
# SECURITY_DELAY         1.000000
# ARR_DELAY              1.000000
# ARR_TIME               1.000000
# TAXI_IN                1.000000
# WHEELS_OFF             0.993279
# TAXI_OUT               0.993279
# DEP_TIME               0.974471
# DEP_DELAY              0.974471
# OP_CARRIER             0.000000
# FL_DATE                0.000000
# CRS_DEP_TIME           0.000000
# OP_CARRIER_FL_NUM      0.000000
# DEST                   0.000000
# ORIGIN                 0.000000
# CRS_ELAPSED_TIME       0.000000
# CANCELLED              0.000000
# CRS_ARR_TIME           0.000000
# DIVERTED               0.000000
# CANCELLATION_CODE      0.000000
# DISTANCE               0.000000
# dtype: float64

# %%
num_cols = [
    "DEP_DELAY", "ARR_DELAY", "AIR_TIME", "TAXI_OUT",
    "TAXI_IN", "DISTANCE", "CARRIER_DELAY", "WEATHER_DELAY",
    "NAS_DELAY", "SECURITY_DELAY", "LATE_AIRCRAFT_DELAY"
]

num_cols = [c for c in num_cols if c in df.columns]  # olup olmayanları ayıkla

print("\n--- Sayısal Kolonların İstatistik Özeti ---")
display(df[num_cols].describe(percentiles=[0.25, 0.5, 0.75, 0.9, 0.95]))
# Out:
# --- Sayısal Kolonların İstatistik Özeti ---
#           DEP_DELAY     ARR_DELAY      AIR_TIME      TAXI_OUT       TAXI_IN  \
# count  1.086816e+06  1.083993e+06  1.083992e+06  1.086427e+06  1.085710e+06
# mean   7.700096e+00  1.355274e+00  1.166288e+02  1.627819e+01  7.251868e+00
# std    3.770703e+01  4.002675e+01  7.310511e+01  9.053513e+00  5.252549e+00
# min   -5.600000e+01 -8.700000e+01  4.000000e+00  1.000000e+00  1.000000e+00
# 25%   -5.000000e+00 -1.600000e+01  6.200000e+01  1.100000e+01  4.000000e+00
# 50%   -2.000000e+00 -7.000000e+00  9.800000e+01  1.400000e+01  6.000000e+00
# 75%    4.000000e+00  5.000000e+00  1.490000e+02  1.900000e+01  8.000000e+00
# 90%    2.900000e+01  2.800000e+01  2.190000e+02  2.600000e+01  1.200000e+01
# 95%    6.000000e+01  5.900000e+01  2.730000e+02  3.200000e+01  1.600000e+01
# max    1.663000e+03  1.660000e+03  7.030000e+02  1.850000e+02  1.570000e+02
#
#            DISTANCE  CARRIER_DELAY  WEATHER_DELAY      NAS_DELAY  \
# count  1.106969e+06  171245.000000  171245.000000  171245.000000
# mean   8.438666e+02      20.304721       2.825005      15.056504
# std    6.092586e+02      57.041878      23.063769      30.127610
# min    3.000000e+01       0.000000       0.000000       0.000000
# 25%    3.910000e+02       0.000000       0.000000       0.000000
# 50%    6.790000e+02       1.000000       0.000000       2.000000
# 75%    1.086000e+03      19.000000       0.000000      19.000000
# 90%    1.721000e+03      52.000000       0.000000      39.000000
# 95%    2.237000e+03      93.000000       4.000000      63.000000
# max    4.983000e+03    1659.000000    1135.000000     810.000000
#
#        SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# count   171245.000000        171245.000000
# mean         0.076329            22.838553
# std          1.947219            44.701141
# min          0.000000             0.000000
# 25%          0.000000             0.000000
# 50%          0.000000             0.000000
# 75%          0.000000            27.000000
# 90%          0.000000            69.000000
# 95%          0.000000           108.000000
# max        242.000000          1208.000000

# %%
# Ensure 'FL_DATE' column is datetime type
import pandas as pd
if not pd.api.types.is_datetime64_any_dtype(df["FL_DATE"]):
    df["FL_DATE"] = pd.to_datetime(df["FL_DATE"])

# 1) NA olmayan saatleri seçme
mask = df["CRS_DEP_TIME"].notna()


# 2) HHMM değerini 4 haneli string

time_str = (
    df.loc[mask, "CRS_DEP_TIME"]
      .astype(int)
      .astype(str)
      .str.zfill(4)
)

# 3) Tarih + saat_string

datetime_str = (
    df.loc[mask, "FL_DATE"].dt.strftime("%Y-%m-%d")
    + " "
    + time_str
)

# 4) Stringi datetime’e dönüştürme
# ===========================
df.loc[mask, "CRS_DEP_DATETIME"] = pd.to_datetime(
    datetime_str,
    format="%Y-%m-%d %H%M"
)

# 5) Saat ve dakika ayrı kolonda
df["CRS_DEP_HOUR"]   = df["CRS_DEP_DATETIME"].dt.hour
df["CRS_DEP_MINUTE"] = df["CRS_DEP_DATETIME"].dt.minute

df[["CRS_DEP_TIME", "CRS_DEP_DATETIME", "CRS_DEP_HOUR", "CRS_DEP_MINUTE"]].head()
# Out:
#    CRS_DEP_TIME    CRS_DEP_DATETIME  CRS_DEP_HOUR  CRS_DEP_MINUTE
# 0          1935 2016-01-01 19:35:00            19              35
# 1          2125 2016-01-01 21:25:00            21              25
# 2          2255 2016-01-01 22:55:00            22              55
# 3          1656 2016-01-01 16:56:00            16              56
# 4           900 2016-01-01 09:00:00             9               0
