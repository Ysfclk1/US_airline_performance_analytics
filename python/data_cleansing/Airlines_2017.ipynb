# %%
import pandas as pd
import zipfile

# ZIP dosyasının göreli yolu
zip_path = "../../data/2017.csv.zip"

# ZIP içeriğini kontrol et
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    print("📦 ZIP içeriği:", zip_ref.namelist())  # ZIP içindeki dosya adlarını göster

    # ZIP içindeki dosya adını buradan al
    with zip_ref.open("2017.csv") as f:
        df_2017 = pd.read_csv(f)

print(f"✅ Yüklendi: {len(df_2017):,} satır")
df_2017.head()
# Out:
# 📦 ZIP içeriği: ['2017.csv']
# ✅ Yüklendi: 5,674,621 satır
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2017-01-01         AA                  1    JFK  LAX           800
# 1  2017-01-01         AA                  2    LAX  JFK           900
# 2  2017-01-01         AA                  4    LAX  JFK          1130
# 3  2017-01-01         AA                  5    DFW  HNL          1135
# 4  2017-01-01         AA                  6    OGG  DFW          1855
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0     831.0       31.0      25.0       856.0  ...             402.0
# 1     934.0       34.0      34.0      1008.0  ...             327.0
# 2    1221.0       51.0      20.0      1241.0  ...             328.0
# 3    1252.0       77.0      19.0      1311.0  ...             517.0
# 4    1855.0        0.0      16.0      1911.0  ...             425.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
df_2017 = pd.read_csv("../../data/2017.csv.zip", compression='zip')

# %%
df_2017
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2017-01-01         AA                  1    JFK  LAX           800
# 1        2017-01-01         AA                  2    LAX  JFK           900
# 2        2017-01-01         AA                  4    LAX  JFK          1130
# 3        2017-01-01         AA                  5    DFW  HNL          1135
# 4        2017-01-01         AA                  6    OGG  DFW          1855
# ...             ...        ...                ...    ...  ...           ...
# 5674616  2017-12-31         UA               2421    IAH  LAS           750
# 5674617  2017-12-31         UA               2425    RSW  ORD          1611
# 5674618  2017-12-31         UA               2426    SNA  DEN          1335
# 5674619  2017-12-31         UA               2427    LAS  SFO          1115
# 5674620  2017-12-31         UA               2429    EWR  DEN          1510
#
# ...

# %%
df_2017.columns
# Out:
# Index(['FL_DATE', 'OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST',
#        'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY',
#        'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'Unnamed: 27'],
#       dtype='object')

# %%
df_2017 = df_2017.drop(columns=["Unnamed: 27"])

# %%
null_info = pd.DataFrame({
    'Null Sayısı': df_2017.isnull().sum(),
    'Null Yüzdesi': (df_2017.isnull().sum() / len(df_2017)) * 100
})
print(null_info)
# Out:
#                      Null Sayısı  Null Yüzdesi
# FL_DATE                        0      0.000000
# OP_CARRIER                     0      0.000000
# OP_CARRIER_FL_NUM              0      0.000000
# ORIGIN                         0      0.000000
# DEST                           0      0.000000
# CRS_DEP_TIME                   0      0.000000
# DEP_TIME                   80308      1.415213
# DEP_DELAY                  80343      1.415830
# TAXI_OUT                   82145      1.447586
# WHEELS_OFF                 82141      1.447515
# WHEELS_ON                  84674      1.492153
# TAXI_IN                    84674      1.492153
# CRS_ARR_TIME                   0      0.000000
# ARR_TIME                   84674      1.492153
# ARR_DELAY                  95211      1.677839
# CANCELLED                      0      0.000000
# CANCELLATION_CODE        5591928     98.542757
# DIVERTED                       0      0.000000
# CRS_ELAPSED_TIME               7      0.000123
# ...

# %%
parse_dates=["FL_DATE"],   # uçuş tarihi
dtype={
        "OP_CARRIER": "category",
        "ORIGIN": "category",
        "DEST": "category"
}
print("Şekil (satır, kolon):", df_2017.shape)
print("\nİlk 5 satır:")
display(df_2017.head())

print("\nKolonlar:")
print(df_2017.columns.tolist())

print("\nDtype bilgisi:")
print(df_2017.dtypes)
# Out:
# Şekil (satır, kolon): (5674621, 27)
#
# İlk 5 satır:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2017-01-01         AA                  1    JFK  LAX           800
# 1  2017-01-01         AA                  2    LAX  JFK           900
# 2  2017-01-01         AA                  4    LAX  JFK          1130
# 3  2017-01-01         AA                  5    DFW  HNL          1135
# 4  2017-01-01         AA                  6    OGG  DFW          1855
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  DIVERTED  CRS_ELAPSED_TIME  \
# 0     831.0       31.0      25.0       856.0  ...       0.0             402.0
# 1     934.0       34.0      34.0      1008.0  ...       0.0             327.0
# 2    1221.0       51.0      20.0      1241.0  ...       0.0             328.0
# 3    1252.0       77.0      19.0      1311.0  ...       0.0             517.0
# 4    1855.0        0.0      16.0      1911.0  ...       0.0             425.0
#
# ...

# %%
# Cancelled ve Diverted ile eksikliği inceleme
if "CANCELLED" in df_2017.columns:
    print("\nCANCELLED dağılımı:")
    display(df_2017["CANCELLED"].value_counts(dropna=False))

if "DIVERTED" in df_2017.columns:
    print("\nDIVERTED dağılımı:")
    display(df_2017["DIVERTED"].value_counts(dropna=False))

# Cancelled satırlarındaki eksiklik
if "CANCELLED" in df_2017.columns:
    print("\nCANCELLED = 1 satırlarda eksik oranları:")
    display(df_2017[df_2017["CANCELLED"] == 1].isna().mean().sort_values(ascending=False))
# Out:
# CANCELLED dağılımı:
# CANCELLED
# 0.0    5591928
# 1.0      82693
# Name: count, dtype: int64
# DIVERTED dağılımı:
# DIVERTED
# 0.0    5662091
# 1.0      12530
# Name: count, dtype: int64
# CANCELLED = 1 satırlarda eksik oranları:
# WHEELS_ON              1.000000
# NAS_DELAY              1.000000
# LATE_AIRCRAFT_DELAY    1.000000
# ACTUAL_ELAPSED_TIME    1.000000
# AIR_TIME               1.000000
# CARRIER_DELAY          1.000000
# WEATHER_DELAY          1.000000
# SECURITY_DELAY         1.000000
# ARR_DELAY              1.000000
# ARR_TIME               1.000000
# TAXI_IN                1.000000
# TAXI_OUT               0.993373
# WHEELS_OFF             0.993325
# DEP_DELAY              0.971570
# DEP_TIME               0.971158
# CRS_ELAPSED_TIME       0.000085
# FL_DATE                0.000000
# OP_CARRIER             0.000000
# OP_CARRIER_FL_NUM      0.000000
# DEST                   0.000000
# ORIGIN                 0.000000
# CRS_DEP_TIME           0.000000
# ...

# %%
num_cols = [
    "DEP_DELAY", "ARR_DELAY", "AIR_TIME", "TAXI_OUT",
    "TAXI_IN", "DISTANCE", "CARRIER_DELAY", "WEATHER_DELAY",
    "NAS_DELAY", "SECURITY_DELAY", "LATE_AIRCRAFT_DELAY"
]

num_cols = [c for c in num_cols if c in df_2017.columns]  # olup olmayanları ayıkla

print("\n--- Sayısal Kolonların İstatistik Özeti ---")
display(df_2017[num_cols].describe(percentiles=[0.25, 0.5, 0.75, 0.9, 0.95]))
# Out:
# --- Sayısal Kolonların İstatistik Özeti ---
#           DEP_DELAY     ARR_DELAY      AIR_TIME      TAXI_OUT       TAXI_IN  \
# count  5.594278e+06  5.579410e+06  5.579410e+06  5.592476e+06  5.589947e+06
# mean   9.725734e+00  4.326357e+00  1.174856e+02  1.677994e+01  7.507610e+00
# std    4.386590e+01  4.586481e+01  7.427621e+01  9.365385e+00  5.913152e+00
# min   -2.340000e+02 -2.380000e+02  7.000000e+00  0.000000e+00  0.000000e+00
# 25%   -5.000000e+00 -1.500000e+01  6.200000e+01  1.100000e+01  4.000000e+00
# 50%   -2.000000e+00 -6.000000e+00  9.800000e+01  1.400000e+01  6.000000e+00
# 75%    6.000000e+00  7.000000e+00  1.490000e+02  2.000000e+01  9.000000e+00
# 90%    3.500000e+01  3.500000e+01  2.250000e+02  2.700000e+01  1.300000e+01
# 95%    7.000000e+01  7.000000e+01  2.800000e+02  3.300000e+01  1.700000e+01
# max    2.755000e+03  2.189000e+03  7.120000e+02  1.830000e+02  4.140000e+02
#
#            DISTANCE  CARRIER_DELAY  WEATHER_DELAY     NAS_DELAY  \
# ...

# %%
# Ensure 'FL_DATE' column is datetime type
import pandas as pd
if not pd.api.types.is_datetime64_any_dtype(df_2017["FL_DATE"]):
    df_2017["FL_DATE"] = pd.to_datetime(df_2017["FL_DATE"])

# 1) NA olmayan saatleri seçme
mask = df_2017["CRS_DEP_TIME"].notna()


# 2) HHMM değerini 4 haneli string

time_str = (
    df_2017.loc[mask, "CRS_DEP_TIME"]
      .astype(int)
      .astype(str)
      .str.zfill(4)
)

# 3) Tarih + saat_string

datetime_str = (
    df_2017.loc[mask, "FL_DATE"].dt.strftime("%Y-%m-%d")
    + " "
    + time_str
)

# 4) Stringi datetime’e dönüştürme
# ===========================
df_2017.loc[mask, "CRS_DEP_DATETIME"] = pd.to_datetime(
    datetime_str,
    format="%Y-%m-%d %H%M"
)

# 5) Saat ve dakika ayrı kolonda
df_2017["CRS_DEP_HOUR"]   = df_2017["CRS_DEP_DATETIME"].dt.hour
df_2017["CRS_DEP_MINUTE"] = df_2017["CRS_DEP_DATETIME"].dt.minute

df_2017[["CRS_DEP_TIME", "CRS_DEP_DATETIME", "CRS_DEP_HOUR", "CRS_DEP_MINUTE"]].head()
# Out:
#    CRS_DEP_TIME    CRS_DEP_DATETIME  CRS_DEP_HOUR  CRS_DEP_MINUTE
# 0           800 2017-01-01 08:00:00             8               0
# 1           900 2017-01-01 09:00:00             9               0
# 2          1130 2017-01-01 11:30:00            11              30
# 3          1135 2017-01-01 11:35:00            11              35
# 4          1855 2017-01-01 18:55:00            18              55

# %%
import os
os.makedirs("../../data/processed", exist_ok=True)
df_2017.to_csv("../../data/processed/airline_2017_cleaned.csv", index=False)
