# %%
import pandas as pd
import zipfile

# ZIP dosyasının göreli yolu
zip_path = "../../data/2018.csv.zip"

# ZIP içeriğini kontrol et
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    print("📦 ZIP içeriği:", zip_ref.namelist())  # ZIP içindeki dosya adlarını göster

    # ZIP içindeki dosya adını buradan al
    with zip_ref.open("2018.csv") as f:
        df_2018 = pd.read_csv(f)

print(f"✅ Yüklendi: {len(df_2018):,} satır")
df_2018.head()
# Out:
# 📦 ZIP içeriği: ['2018.csv']
# ✅ Yüklendi: 7,213,446 satır
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2018-01-01         UA               2429    EWR  DEN          1517
# 1  2018-01-01         UA               2427    LAS  SFO          1115
# 2  2018-01-01         UA               2426    SNA  DEN          1335
# 3  2018-01-01         UA               2425    RSW  ORD          1546
# 4  2018-01-01         UA               2424    ORD  ALB           630
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1512.0       -5.0      15.0      1527.0  ...             268.0
# 1    1107.0       -8.0      11.0      1118.0  ...              99.0
# 2    1330.0       -5.0      15.0      1345.0  ...             134.0
# 3    1552.0        6.0      19.0      1611.0  ...             190.0
# 4     650.0       20.0      13.0       703.0  ...             112.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
df_2018 = pd.read_csv("../../data/2018.csv.zip", compression='zip')

# %%
df_2018
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2018-01-01         UA               2429    EWR  DEN          1517
# 1        2018-01-01         UA               2427    LAS  SFO          1115
# 2        2018-01-01         UA               2426    SNA  DEN          1335
# 3        2018-01-01         UA               2425    RSW  ORD          1546
# 4        2018-01-01         UA               2424    ORD  ALB           630
# ...             ...        ...                ...    ...  ...           ...
# 7213441  2018-12-31         AA               1815    DCA  CLT          1534
# 7213442  2018-12-31         AA               1816    CLT  DFW          1751
# 7213443  2018-12-31         AA               1817    CLT  MEM          2015
# 7213444  2018-12-31         AA               1818    CLT  RDU          1300
# 7213445  2018-12-31         AA               1818    RDU  CLT          1435
#
# ...

# %%
df_2018.columns
# Out:
# Index(['FL_DATE', 'OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST',
#        'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY',
#        'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'Unnamed: 27'],
#       dtype='object')

# %%
df_2018 = df_2018.drop(columns=["Unnamed: 27"])

# %%
null_info = pd.DataFrame({
    'Null Sayısı': df_2018.isnull().sum(),
    'Null Yüzdesi': (df_2018.isnull().sum() / len(df_2018)) * 100
})
print(null_info)
# Out:
#                      Null Sayısı  Null Yüzdesi
# FL_DATE                        0      0.000000
# OP_CARRIER                     0      0.000000
# OP_CARRIER_FL_NUM              0      0.000000
# ORIGIN                         0      0.000000
# DEST                           0      0.000000
# CRS_DEP_TIME                   0      0.000000
# DEP_TIME                  112317      1.557051
# DEP_DELAY                 117234      1.625215
# TAXI_OUT                  115830      1.605751
# WHEELS_OFF                115829      1.605737
# WHEELS_ON                 119246      1.653107
# TAXI_IN                   119246      1.653107
# CRS_ARR_TIME                   0      0.000000
# ARR_TIME                  119245      1.653093
# ARR_DELAY                 137040      1.899785
# CANCELLED                      0      0.000000
# CANCELLATION_CODE        7096862     98.383796
# DIVERTED                       0      0.000000
# CRS_ELAPSED_TIME              10      0.000139
# ...

# %%
parse_dates=["FL_DATE"],   # uçuş tarihi
dtype={
        "OP_CARRIER": "category",
        "ORIGIN": "category",
        "DEST": "category"
}
print("Şekil (satır, kolon):", df_2018.shape)
print("\nİlk 5 satır:")
display(df_2018.head())

print("\nKolonlar:")
print(df_2018.columns.tolist())

print("\nDtype bilgisi:")
print(df_2018.dtypes)
# Out:
# Şekil (satır, kolon): (7213446, 27)
#
# İlk 5 satır:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2018-01-01         UA               2429    EWR  DEN          1517
# 1  2018-01-01         UA               2427    LAS  SFO          1115
# 2  2018-01-01         UA               2426    SNA  DEN          1335
# 3  2018-01-01         UA               2425    RSW  ORD          1546
# 4  2018-01-01         UA               2424    ORD  ALB           630
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  DIVERTED  CRS_ELAPSED_TIME  \
# 0    1512.0       -5.0      15.0      1527.0  ...       0.0             268.0
# 1    1107.0       -8.0      11.0      1118.0  ...       0.0              99.0
# 2    1330.0       -5.0      15.0      1345.0  ...       0.0             134.0
# 3    1552.0        6.0      19.0      1611.0  ...       0.0             190.0
# 4     650.0       20.0      13.0       703.0  ...       0.0             112.0
#
# ...

# %%
# Cancelled ve Diverted ile eksikliği inceleme
if "CANCELLED" in df_2018.columns:
    print("\nCANCELLED dağılımı:")
    display(df_2018["CANCELLED"].value_counts(dropna=False))

if "DIVERTED" in df_2018.columns:
    print("\nDIVERTED dağılımı:")
    display(df_2018["DIVERTED"].value_counts(dropna=False))

# Cancelled satırlarındaki eksiklik
if "CANCELLED" in df_2018.columns:
    print("\nCANCELLED = 1 satırlarda eksik oranları:")
    display(df_2018[df_2018["CANCELLED"] == 1].isna().mean().sort_values(ascending=False))
# Out:
# CANCELLED dağılımı:
# CANCELLED
# 0.0    7096862
# 1.0     116584
# Name: count, dtype: int64
# DIVERTED dağılımı:
# DIVERTED
# 0.0    7195587
# 1.0      17859
# Name: count, dtype: int64
# CANCELLED = 1 satırlarda eksik oranları:
# WHEELS_ON              1.000000
# NAS_DELAY              1.000000
# LATE_AIRCRAFT_DELAY    1.000000
# ACTUAL_ELAPSED_TIME    1.000000
# AIR_TIME               1.000000
# CARRIER_DELAY          1.000000
# WEATHER_DELAY          1.000000
# SECURITY_DELAY         1.000000
# ARR_DELAY              1.000000
# ARR_TIME               1.000000
# TAXI_IN                1.000000
# TAXI_OUT               0.993533
# WHEELS_OFF             0.993524
# DEP_DELAY              0.964892
# DEP_TIME               0.963400
# CRS_ELAPSED_TIME       0.000026
# FL_DATE                0.000000
# OP_CARRIER             0.000000
# OP_CARRIER_FL_NUM      0.000000
# DEST                   0.000000
# ORIGIN                 0.000000
# CRS_DEP_TIME           0.000000
# ...

# %%
num_cols = [
    "DEP_DELAY", "ARR_DELAY", "AIR_TIME", "TAXI_OUT",
    "TAXI_IN", "DISTANCE", "CARRIER_DELAY", "WEATHER_DELAY",
    "NAS_DELAY", "SECURITY_DELAY", "LATE_AIRCRAFT_DELAY"
]

num_cols = [c for c in num_cols if c in df_2018.columns]  # olup olmayanları ayıkla

print("\n--- Sayısal Kolonların İstatistik Özeti ---")
display(df_2018[num_cols].describe(percentiles=[0.25, 0.5, 0.75, 0.9, 0.95]))
# Out:
# --- Sayısal Kolonların İstatistik Özeti ---
#           DEP_DELAY     ARR_DELAY      AIR_TIME      TAXI_OUT       TAXI_IN  \
# count  7.096212e+06  7.076406e+06  7.079004e+06  7.097616e+06  7.094200e+06
# mean   9.969858e+00  5.048581e+00  1.115020e+02  1.741061e+01  7.601246e+00
# std    4.482964e+01  4.692664e+01  7.111293e+01  9.920409e+00  6.064797e+00
# min   -1.220000e+02 -1.200000e+02  7.000000e+00  1.000000e+00  1.000000e+00
# 25%   -5.000000e+00 -1.400000e+01  6.000000e+01  1.100000e+01  4.000000e+00
# 50%   -2.000000e+00 -6.000000e+00  9.200000e+01  1.500000e+01  6.000000e+00
# 75%    7.000000e+00  8.000000e+00  1.410000e+02  2.000000e+01  9.000000e+00
# 90%    3.700000e+01  3.700000e+01  2.110000e+02  2.800000e+01  1.400000e+01
# 95%    7.300000e+01  7.300000e+01  2.700000e+02  3.500000e+01  1.800000e+01
# max    2.710000e+03  2.692000e+03  6.960000e+02  1.960000e+02  2.590000e+02
#
#            DISTANCE  CARRIER_DELAY  WEATHER_DELAY     NAS_DELAY  \
# ...

# %%
# Ensure 'FL_DATE' column is datetime type
import pandas as pd
if not pd.api.types.is_datetime64_any_dtype(df_2018["FL_DATE"]):
    df_2018["FL_DATE"] = pd.to_datetime(df_2018["FL_DATE"])

# 1) NA olmayan saatleri seçme
mask = df_2018["CRS_DEP_TIME"].notna()


# 2) HHMM değerini 4 haneli string

time_str = (
    df_2018.loc[mask, "CRS_DEP_TIME"]
      .astype(int)
      .astype(str)
      .str.zfill(4)
)

# 3) Tarih + saat_string

datetime_str = (
    df_2018.loc[mask, "FL_DATE"].dt.strftime("%Y-%m-%d")
    + " "
    + time_str
)

# 4) Stringi datetime’e dönüştürme
# ===========================
df_2018.loc[mask, "CRS_DEP_DATETIME"] = pd.to_datetime(
    datetime_str,
    format="%Y-%m-%d %H%M"
)

# 5) Saat ve dakika ayrı kolonda
df_2018["CRS_DEP_HOUR"]   = df_2018["CRS_DEP_DATETIME"].dt.hour
df_2018["CRS_DEP_MINUTE"] = df_2018["CRS_DEP_DATETIME"].dt.minute

df_2018[["CRS_DEP_TIME", "CRS_DEP_DATETIME", "CRS_DEP_HOUR", "CRS_DEP_MINUTE"]].head()
# Out:
#    CRS_DEP_TIME    CRS_DEP_DATETIME  CRS_DEP_HOUR  CRS_DEP_MINUTE
# 0          1517 2018-01-01 15:17:00            15              17
# 1          1115 2018-01-01 11:15:00            11              15
# 2          1335 2018-01-01 13:35:00            13              35
# 3          1546 2018-01-01 15:46:00            15              46
# 4           630 2018-01-01 06:30:00             6              30

# %%
import os
os.makedirs("../../data/processed", exist_ok=True)
df_2018.to_csv("../../data/processed/airline_2018_cleaned.csv", index=False)
